# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Path = r"C:\Users\Lenovo\Documents\GitHub\CreditCard_Analysis\data\sanitized_credit_card_transaction.csv"
df = pd.read_csv(Path)

# %% [markdown]
# # Data Information

# %%
df.shape
# Out:
# (1296674, 19)

# %%
df.head()
# Out:
#    2019-01-01 00:00:18  445          fraud_Rippin, Kub and Mann  \
# 0  2019-01-01 00:00:44   43     fraud_Heller, Gutmann and Zieme
# 1  2019-01-01 00:00:51  238                fraud_Lind-Buckridge
# 2  2019-01-01 00:01:16  510  fraud_Kutch, Hermiston and Farrell
# 3  2019-01-01 00:03:06  369                 fraud_Keeling-Crist
# 4  2019-01-01 00:04:08  755    fraud_Stroman, Hudson and Erdman
#
#         misc_net    4.97  F Moravian Falls  NC  286  36.0788  -81.1781  3495  \
# 0    grocery_pos  107.23  F         Orient  WA  991  48.8878 -118.2105   149
# 1  entertainment  220.11  M     Malad City  ID  832  42.1808 -112.2620  4154
# 2  gas_transport   45.00  M        Boulder  MT  596  46.2306 -112.1138  1939
# 3       misc_pos   41.96  M       Doe Hill  VA  244  38.4207  -79.4629    99
# 4  gas_transport   94.63  F         Dublin  PA  189  40.3750  -75.2045  2158
#
#            Psychologist, counselling  37.0000  \
# 0  Special educational needs teacher     47.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296674 entries, 0 to 1296673
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   2019-01-01 00:00:18               1296674 non-null  object
#  1   445                               1296674 non-null  int64
#  2   fraud_Rippin, Kub and Mann        1296674 non-null  object
#  3   misc_net                          1296674 non-null  object
#  4   4.97                              1296674 non-null  float64
#  5   F                                 1296674 non-null  object
#  6   Moravian Falls                    1296674 non-null  object
#  7   NC                                1296674 non-null  object
#  8   286                               1296674 non-null  int64
#  9   36.0788                           1296674 non-null  float64
#  10  -81.1781                          1296674 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Category
def category_trans(category):
    s = category.strip().lower()

    if pd.isna(category):
        return np.nan
    
    else:
        try:
            for i in s:
                cat = s.split('_')
                return cat[0]
        except ValueError:
            return np.nan

df['category'] = df['category'].apply(category_trans)

# %%
#Transaction Time Features
df['hour'] = df['trans_date_trans_time'].dt.hour
df['dayofweek'] = df['trans_date_trans_time'].dt.dayofweek
df['month'] = df['trans_date_trans_time'].dt.month
df['weekend'] = ()

# %%
#Distance between merchant and customer
df['distance'] = np.sqrt((df['lat']-df['merch_lat'])**2+(df['long']-df['merch_long'])**2)

# %%
df
# Out:
#         trans_date_trans_time               cc_num  \
# 0         2019-01-01 00:00:18     2703186189652095
# 1         2019-01-01 00:00:44         630423337322
# 2         2019-01-01 00:00:51       38859492057661
# 3         2019-01-01 00:01:16     3534093764340240
# 4         2019-01-01 00:03:06      375534208663984
# ...                       ...                  ...
# 1296670   2020-06-21 12:12:08       30263540414123
# 1296671   2020-06-21 12:12:19     6011149206456997
# 1296672   2020-06-21 12:12:32     3514865930894695
# 1296673   2020-06-21 12:13:36     2720012583106919
# 1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt gender  \
# 0                 fraud_Rippin, Kub and Mann           misc    4.97      F
# 1            fraud_Heller, Gutmann and Zieme        grocery  107.23      F
# 2                       fraud_Lind-Buckridge  entertainment  220.11      M
# ...
