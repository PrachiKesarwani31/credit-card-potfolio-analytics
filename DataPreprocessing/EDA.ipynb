# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"C:\Users\Lenovo\Documents\GitHub\CreditCard_Analysis\data\featured_credit_card_transaction.csv"
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (1296675, 26)

# %%
df
# Out:
#              trans_date_time  cc_num_key                             merchant  \
# 0        2019-01-01 00:00:18         445           fraud_Rippin, Kub and Mann
# 1        2019-01-01 00:00:44          43      fraud_Heller, Gutmann and Zieme
# 2        2019-01-01 00:00:51         238                 fraud_Lind-Buckridge
# 3        2019-01-01 00:01:16         510   fraud_Kutch, Hermiston and Farrell
# 4        2019-01-01 00:03:06         369                  fraud_Keeling-Crist
# ...                      ...         ...                                  ...
# 1296670  2020-06-21 12:12:08         180                    fraud_Reichel Inc
# 1296671  2020-06-21 12:12:19         814             fraud_Abernathy and Sons
# 1296672  2020-06-21 12:12:32         475                 fraud_Stiedemann Ltd
# 1296673  2020-06-21 12:13:36         452  fraud_Reinger, Weissnat and Strosin
# 1296674  2020-06-21 12:13:37         918  fraud_Langosh, Wintheiser and Hyatt
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 26 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   trans_date_time  1296675 non-null  object
#  1   cc_num_key       1296675 non-null  int64
#  2   merchant         1296675 non-null  object
#  3   category         1296675 non-null  object
#  4   amt              1296675 non-null  float64
#  5   gender           1296675 non-null  object
#  6   city             1296675 non-null  object
#  7   state            1296675 non-null  object
#  8   trunc_zip        1296675 non-null  int64
#  9   lat              1296675 non-null  float64
#  10  lon              1296675 non-null  float64
#  11  city_pop         1296675 non-null  int64
#  12  job              1296675 non-null  object
#  13  age              1296675 non-null  int64
#  14  trans_num        1296675 non-null  object
#  15  merch_lat        1296675 non-null  float64
# ...

# %%
df.describe()
# Out:
#          cc_num_key           amt     trunc_zip           lat           lon  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   4.910549e+02  7.035104e+01  5.172134e+02  3.853762e+01 -9.022634e+01
# std    2.815013e+02  1.603160e+02  2.493472e+02  5.075808e+00  1.375908e+01
# min    1.000000e+00  1.000000e+00  1.000000e+02  2.002710e+01 -1.656723e+02
# 25%    2.490000e+02  9.650000e+00  3.040000e+02  3.462050e+01 -9.679800e+01
# 50%    4.860000e+02  4.752000e+01  5.050000e+02  3.935430e+01 -8.747690e+01
# 75%    7.330000e+02  8.314000e+01  7.250000e+02  4.194040e+01 -8.015800e+01
# max    9.830000e+02  2.894890e+04  9.970000e+02  6.669330e+01 -6.795030e+01
#
#            city_pop           age     merch_lat    merch_long      is_fraud  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   8.882444e+04  5.284240e+01  3.853734e+01 -9.022646e+01  5.788652e-03
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
#1. Distribution of numerical variables
fig, axes = plt.subplots(nrows=6,ncols=2,figsize=(10,20))
col = ['amt','age','distance','hour','dayofweek','month']
for i in range(len(col)):
    sns.boxplot(df,x=col[i],ax=axes[i,0])
    sns.histplot(df,x=col[i],ax=axes[i,1],kde=True)

# %%
 # Categorical variable
col = ['is_fraud','category','gender']

fig, axes = plt.subplots(nrows=3,ncols=1,figsize=(10,20))

for i in range(len(col)):
    sns.countplot(data=df,x=col[i],ax=axes[i])

# %% [markdown]
# ## Bivariate Analysis

# %%
#Behavioural Analysis
#1. Age by Amount
fig, axes = plt.subplots(nrows=2,ncols=1,figsize=(10,10))

s_amt = df.groupby('age_bucket',as_index=False)['amt'].sum()
s_amt = s_amt.sort_values(by='amt',ascending=False)
sns.barplot(data=s_amt,x='age_bucket',y='amt',ax=axes[0])
axes[0].set_title('Amount by Age buckets')

#2. Gender by Amount
sg = df.groupby('gender',as_index=False)['amt'].sum()
sg = sg.sort_values(by='amt',ascending=False)
sns.barplot(data=sg,x='gender',y='amt',ax=axes[1])
axes[1].set_title('Amount by Gender')
# Out:
# Text(0.5, 1.0, 'Amount by Gender')

# %%
#Merchant Analysis
fig, axes = plt.subplots()
